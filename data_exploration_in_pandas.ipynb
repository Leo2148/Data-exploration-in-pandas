# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
## Load text file via read_csv
df = pd.read_csv("banking.csv")
df
# Out:
#       Age  Education   Income  HomeVal    Wealth  Balance
# 0    35.9       14.8  91033.0   183104  220741.0    38517
# 1    37.7       13.8  86748.0   163843  223152.0    40618
# 2    36.8       13.8  72245.0   142732  176926.0    35206
# 3    35.3       13.2  70639.0   145024  166260.0    33434
# 4    35.3       13.2  64879.0   135951  148868.0    28162
# ..    ...        ...      ...      ...       ...      ...
# 97   22.8       12.3  16590.0    67850   24999.0    10436
# 98   30.3       12.2   9354.0    91708   24999.0     9904
# 99   22.0       12.0  14115.0    53923   24999.0     9071
# 100  30.8       11.9  17992.0    46885   24999.0    10679
# 101  35.1       11.0   7741.0    99375   24999.0     6207
#
# [102 rows x 6 columns]

# %%
df.head(5)
# Out:
#     Age  Education   Income  HomeVal    Wealth  Balance
# 0  35.9       14.8  91033.0   183104  220741.0    38517
# 1  37.7       13.8  86748.0   163843  223152.0    40618
# 2  36.8       13.8  72245.0   142732  176926.0    35206
# 3  35.3       13.2  70639.0   145024  166260.0    33434
# 4  35.3       13.2  64879.0   135951  148868.0    28162

# %%
df.columns
# Out:
# Index(['Age', 'Education', 'Income', 'HomeVal', 'Wealth', 'Balance'], dtype='object')

# %%
df.values
# Out:
# array([[3.59000e+01, 1.48000e+01, 9.10330e+04, 1.83104e+05, 2.20741e+05,
#         3.85170e+04],
#        [3.77000e+01, 1.38000e+01, 8.67480e+04, 1.63843e+05, 2.23152e+05,
#         4.06180e+04],
#        [3.68000e+01, 1.38000e+01, 7.22450e+04, 1.42732e+05, 1.76926e+05,
#         3.52060e+04],
#        [3.53000e+01, 1.32000e+01, 7.06390e+04, 1.45024e+05, 1.66260e+05,
#         3.34340e+04],
#        [3.53000e+01, 1.32000e+01, 6.48790e+04, 1.35951e+05, 1.48868e+05,
#         2.81620e+04],
#        [3.48000e+01, 1.37000e+02, 7.55910e+04, 1.55334e+05, 1.88310e+05,
#         3.67080e+04],
#        [3.93000e+01, 1.44000e+01, 8.06150e+04, 1.81265e+05, 2.01743e+05,
#         3.87660e+04],
#        [3.66000e+01, 1.39000e+01, 7.65070e+04, 1.49880e+05, 1.89727e+05,
#         3.48110e+04],
#        [3.57000e+01, 1.61000e+01, 1.07935e+05, 2.76139e+05, 2.11085e+05,
#         4.10320e+04],
#        [4.05000e+01, 1.51000e+01, 8.25570e+04, 1.82088e+05, 2.20782e+05,
#         4.17420e+04],
# ...

# %%
## Get column dtypes
df.dtypes
# Out:
# Age          float64
# Education    float64
# Income       float64
# HomeVal        int64
# Wealth       float64
# Balance        int64
# dtype: object

# %%
## Assign column to new object
income_df = df["Income"]
income_df
# Out:
# 0      91033.0
# 1      86748.0
# 2      72245.0
# 3      70639.0
# 4      64879.0
#         ...
# 97     16590.0
# 98      9354.0
# 99     14115.0
# 100    17992.0
# 101     7741.0
# Name: Income, Length: 102, dtype: float64

# %%
## Select column directly using the attribute
df.Income
# Out:
# 0      91033.0
# 1      86748.0
# 2      72245.0
# 3      70639.0
# 4      64879.0
#         ...
# 97     16590.0
# 98      9354.0
# 99     14115.0
# 100    17992.0
# 101     7741.0
# Name: Income, Length: 102, dtype: float64

# %%
## Additional print statements with some formatting
print("Means: \n", df[["Age","Education","Income"]].mean())
print()
print("Standard Deviations: \n", df[["Age","Education","Income"]].std())
# Out:
# Means:
#  Age             35.451961
# Education       15.303922
# Income       48956.330000
# dtype: float64
#
# Standard Deviations:
#  Age              3.886476
# Education       16.562213
# Income       19451.885607
# dtype: float64

# %%
## Print statement
print("Mean Income: ", income_df.mean())
# Out:
# Mean Income:  48956.33

# %%
## perform descriptive statistics
df.describe(include='all') #include=all for categorical variables
# Out:
#               Age   Education         Income        HomeVal         Wealth  \
# count  102.000000  102.000000     100.000000     102.000000     100.000000
# mean    35.451961   15.303922   48956.330000  106844.725490  108909.220000
# std      3.886476   16.562213   19451.885607   38795.325726   60298.545532
# min     19.500000   11.000000    7741.000000   40313.000000   24999.000000
# 25%     33.925000   12.400000   35442.750000   83016.500000   69733.750000
# 50%     36.100000   12.700000   47655.500000   97743.500000  102348.000000
# 75%     37.575000   13.200000   60384.750000  121790.500000  141482.000000
# max     43.100000  137.000000  111548.000000  276139.000000  331009.000000
#
#             Balance
# count    102.000000
# mean   24887.882353
# std     8697.811347
# min     5956.000000
# 25%    20035.500000
# 50%    24660.500000
# 75%    29180.250000
# max    56569.000000

# %%
pd.isnull(df.Income)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# Name: Income, Length: 102, dtype: bool

# %%
df[pd.isnull(df.Income)]
# Out:
#      Age  Education  Income  HomeVal    Wealth  Balance
# 18  36.2       12.9     NaN   112649  117441.0    26785
# 91  29.6       12.1     NaN    52096   24999.0    13693

# %%
df[pd.isnull(df.Wealth)]
# Out:
#      Age  Education   Income  HomeVal  Wealth  Balance
# 24  34.4       12.8  60753.0    95869     NaN    26773
# 64  33.1       12.2  37287.0    75561     NaN    19343

# %%
df.dropna().describe()
# Out:
#              Age   Education         Income        HomeVal         Wealth  \
# count  98.000000   98.000000      98.000000      98.000000      98.000000
# mean   35.538776   15.418367   48955.030612  107775.377551  109678.387755
# std     3.910589   16.890114   19579.042726   39034.438594   60307.104929
# min    19.500000   11.000000    7741.000000   40313.000000   24999.000000
# 25%    34.075000   12.400000   35078.250000   84140.000000   70262.750000
# 50%    36.100000   12.700000   47655.500000   99441.500000  102348.000000
# 75%    37.675000   13.275000   60157.000000  122968.500000  142994.000000
# max    43.100000  137.000000  111548.000000  276139.000000  331009.000000
#
#             Balance
# count     98.000000
# mean   25020.102041
# std     8779.020839
# min     5956.000000
# 25%    20177.250000
# 50%    24660.500000
# 75%    29309.750000
# max    56569.000000

# %%
df.describe()
# Out:
#               Age   Education         Income        HomeVal         Wealth  \
# count  102.000000  102.000000     100.000000     102.000000     100.000000
# mean    35.451961   15.303922   48956.330000  106844.725490  108909.220000
# std      3.886476   16.562213   19451.885607   38795.325726   60298.545532
# min     19.500000   11.000000    7741.000000   40313.000000   24999.000000
# 25%     33.925000   12.400000   35442.750000   83016.500000   69733.750000
# 50%     36.100000   12.700000   47655.500000   97743.500000  102348.000000
# 75%     37.575000   13.200000   60384.750000  121790.500000  141482.000000
# max     43.100000  137.000000  111548.000000  276139.000000  331009.000000
#
#             Balance
# count    102.000000
# mean   24887.882353
# std     8697.811347
# min     5956.000000
# 25%    20035.500000
# 50%    24660.500000
# 75%    29180.250000
# max    56569.000000

# %%
df2 = df.dropna()
df2.describe()
# Out:
#              Age   Education         Income        HomeVal         Wealth  \
# count  98.000000   98.000000      98.000000      98.000000      98.000000
# mean   35.538776   15.418367   48955.030612  107775.377551  109678.387755
# std     3.910589   16.890114   19579.042726   39034.438594   60307.104929
# min    19.500000   11.000000    7741.000000   40313.000000   24999.000000
# 25%    34.075000   12.400000   35078.250000   84140.000000   70262.750000
# 50%    36.100000   12.700000   47655.500000   99441.500000  102348.000000
# 75%    37.675000   13.275000   60157.000000  122968.500000  142994.000000
# max    43.100000  137.000000  111548.000000  276139.000000  331009.000000
#
#             Balance
# count     98.000000
# mean   25020.102041
# std     8779.020839
# min     5956.000000
# 25%    20177.250000
# 50%    24660.500000
# 75%    29309.750000
# max    56569.000000

# %%
## Finding all instances when the education is above 14
education_above_14 = df2.Education>14
df2[education_above_14].Education.sort_values()
# Out:
# 41     14.1
# 47     14.1
# 10     14.2
# 6      14.4
# 0      14.8
# 9      15.1
# 11     15.8
# 8      16.1
# 14     16.1
# 20     16.1
# 58     16.1
# 84     16.1
# 30    126.0
# 5     137.0
# Name: Education, dtype: float64

# %%
df2[df2.Education>17].Education.sort_values()
# Out:
# 30    126.0
# 5     137.0
# Name: Education, dtype: float64

# %%
pop_df3 = df2.copy()
pop_df3.loc[pop_df3.Education>17] = df2[df2.Education>17]/10
pop_df3.describe()
# Out:
#              Age  Education         Income        HomeVal         Wealth  \
# count  98.000000  98.000000      98.000000      98.000000      98.000000
# mean   34.912449  13.003061   47755.854082  105378.613265  106783.335714
# std     6.010605   1.018231   20281.316691   40983.635682   61185.993144
# min     3.340000  11.000000    5498.600000   10564.700000   12692.900000
# 25%    33.925000  12.400000   34090.250000   82757.500000   62951.500000
# 50%    36.100000  12.700000   46863.000000   95801.000000  100236.500000
# 75%    37.675000  13.200000   59455.000000  121790.500000  140344.250000
# max    43.100000  16.100000  111548.000000  276139.000000  331009.000000
#
#             Balance
# count     98.000000
# mean   24456.417347
# std     9234.890292
# min     2467.100000
# 25%    19402.000000
# 50%    24317.000000
# 75%    29180.250000
# max    56569.000000

# %%
pop_df3 = df2.copy()
pop_df3.loc[pop_df3.Education>17] = df2.Education.mean()
pop_df3.describe()
# Out:
#              Age  Education         Income        HomeVal         Wealth  \
# count  98.000000  98.000000      98.000000      98.000000      98.000000
# mean   35.157518  13.049354   47622.926905  105112.620783  106461.977926
# std     4.841497   1.071555   20572.801951   41624.350486   61706.106799
# min    15.418367  11.000000      15.418367      15.418367      15.418367
# 25%    33.925000  12.400000   34090.250000   82757.500000   62951.500000
# 50%    36.100000  12.700000   46863.000000   95801.000000  100236.500000
# 75%    37.675000  13.275000   59455.000000  121790.500000  140344.250000
# max    43.100000  16.100000  111548.000000  276139.000000  331009.000000
#
#             Balance
# count     98.000000
# mean   24394.100375
# std     9389.203383
# min       15.418367
# 25%    19402.000000
# 50%    24317.000000
# 75%    29180.250000
# max    56569.000000

# %%
pop_df3.corr()
# Out:
#                 Age  Education    Income   HomeVal    Wealth   Balance
# Age        1.000000  -0.068961  0.563620  0.498028  0.512850  0.644577
# Education -0.068961   1.000000  0.402471  0.542952  0.343383  0.358369
# Income     0.563620   0.402471  1.000000  0.818060  0.946405  0.956866
# HomeVal    0.498028   0.542952  0.818060  1.000000  0.713731  0.791344
# Wealth     0.512850   0.343383  0.946405  0.713731  1.000000  0.944666
# Balance    0.644577   0.358369  0.956866  0.791344  0.944666  1.000000

# %% [markdown]
# # Basic visualizations

# %%
df = pop_df3.copy()

# %% [markdown]
# Analize distributions of each attribute

# %%
for col in df.columns:
    if col != 'Balance':
        df.plot(x=col, y='Balance', kind="scatter")
        plt.title(col+" and Balance")
        plt.show()

# %%
# plot histogram and boxplot for each attribute
for col in df.columns:
    df.hist(col)
    plt.show()
    df.boxplot(col)
    plt.show()

# %% [markdown]
# See scatterplot between each attribute and the dependant variable

# %%
df.Age.hist()
# Out:
# <Axes: >
